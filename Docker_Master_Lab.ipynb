# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/docker-for-data-science/blob/main/Docker_Master_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# pwd = Print Working Directory

# %%
#List Files
# !ls
# Out:
# sample_data

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Aug 24 13:21 .
# drwxr-xr-x 1 root root 4096 Aug 27 03:40 ..
# drwxr-xr-x 4 root root 4096 Aug 24 13:21 .config
# drwxr-xr-x 1 root root 4096 Aug 24 13:21 sample_data

# %%
#Create directory
# !mkdir docker-practice

# %%
#Move directory in Colab
# %cd docker-practice
# Out:
# /content/docker-practice

# %%
#Move directory in VS Code
#cd docker-practice

# %%
#Create file
# !touch test.txt

# %%
#Write file
# !echo "Hello Docker" > test.txt

# %%
# !cat test.txt
# Out:
# Hello Docker

# %%
#Append
# !echo "Learning Docker" >> test.txt

# %%
# !cat test.txt
# Out:
# Hello Docker
# Learning Docker

# %%
#Learn Pipes
# !docker ps -a | grep flask
# Out:
# /bin/bash: line 1: docker: command not found

# %% [markdown]
# |: Send the output of the first command into the second command.

# %%
#Learn Environment Variables
# !export APP_ENV=development

# %%
# !echo $APP_ENV

# %%
#In Docker:

#docker run -e APP_ENV=production ...

# %%
#Master Docker Images in VS Code
#docker images

# %%
#docker image ls

# %%
#Inspect in VS Code
#docker image inspect IMAGE_NAME

# %%
#Remove in VS Code
#docker rmi IMAGE_NAME

# %% [markdown]
# Master docker build in VS Code
#
# Create Dockerfile in VS Code

# %%
#FROM python:3.11-slim

#WORKDIR /app

#COPY requirements.txt .

#RUN pip install --no-cache-dir -r requirements.txt

#COPY app.py .

#CMD ["python", "app.py"]

# %%
#Build
#docker build -t myapp .

# %%
#Now change the tag:
#docker build -t myapp:1.0 .

# %% [markdown]
# Master docker run

# %%
#docker run hello-world

# %%
#docker run python:3.11 python --version

# %%
#docker run python:3.11 echo "Hello Docker"

# %%
#docker run -it python:3.11 bash

# %%
#exit

# %% [markdown]
# Understand -it

# %%
#docker run -it python:3.11 bash

# %%
#-i = interactive
#-t = terminal

# %%
#docker run -d --name test-container python:3.11 sleep 3600

# %%
#docker ps

# %%
#docker ps -a

# %%
#docker start test-container

# %%
#docker restart test-container

# %%
#Remove
#docker rm test-container

# %%
#docker run
#vs
#docker start

# %%
#Master Container Logs

#docker run -d \
    #--name log-test \
    #python:3.11 \
    #sh -c "while true; do echo Docker-learning; sleep 2; done"

# %%
#docker logs log-test

# %%
#docker logs -f log-test

# %%
#docker logs --tail 10 log-test

# %%
#Master docker exec

#docker exec log-test ls
#docker exec log-test python --version
#docker exec -it log-test bash
